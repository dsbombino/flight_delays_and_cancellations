# %%
import reads.reads as r
import pandas as pd
pd.set_option("display.max_columns", None)

# %%
stream_airlines = 'C:./Data/2015 Flight Delays and Cancellations/airlines.csv'
stream_airports = 'C:./Data/2015 Flight Delays and Cancellations/airports.csv'
stream_flights = 'C:./Data/2015 Flight Delays and Cancellations/flights.csv'

# %%
flights = r.read_flight(stream_flights)
flights
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0        2015      1    1            4      AS             98      N407AS
# 1        2015      1    1            4      AA           2336      N3KUAA
# 2        2015      1    1            4      US            840      N171US
# 3        2015      1    1            4      AA            258      N3HYAA
# 4        2015      1    1            4      AS            135      N527AS
# ...       ...    ...  ...          ...     ...            ...         ...
# 5819074  2015     12   31            4      B6            688      N657JB
# 5819075  2015     12   31            4      B6            745      N828JB
# 5819076  2015     12   31            4      B6           1503      N913JB
# 5819077  2015     12   31            4      B6            333      N527JB
# 5819078  2015     12   31            4      B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT SCHEDULED_DEPARTURE DEPARTURE_TIME  \
# ...

# %%
airlines = r.read_airlines(stream_airlines)
airlines
# Out:
#    IATA_CODE                       AIRLINE
# 0         UA         United Air Lines Inc.
# 1         AA        American Airlines Inc.
# 2         US               US Airways Inc.
# 3         F9        Frontier Airlines Inc.
# 4         B6               JetBlue Airways
# 5         OO         Skywest Airlines Inc.
# 6         AS          Alaska Airlines Inc.
# 7         NK              Spirit Air Lines
# 8         WN        Southwest Airlines Co.
# 9         DL          Delta Air Lines Inc.
# 10        EV   Atlantic Southeast Airlines
# 11        HA        Hawaiian Airlines Inc.
# 12        MQ  American Eagle Airlines Inc.
# 13        VX                Virgin America

# %%
airports = r.read_airports(stream_airports)
airports
# Out:
#     IATA_CODE                              AIRPORT  \
# 0         ABE  Lehigh Valley International Airport
# 1         ABI             Abilene Regional Airport
# 2         ABQ    Albuquerque International Sunport
# 3         ABR            Aberdeen Regional Airport
# 4         ABY   Southwest Georgia Regional Airport
# ..        ...                                  ...
# 317       WRG                     Wrangell Airport
# 318       WYS               Westerly State Airport
# 319       XNA  Northwest Arkansas Regional Airport
# 320       YAK                      Yakutat Airport
# 321       YUM           Yuma International Airport
#
#                                CITY STATE COUNTRY  LATITUDE  LONGITUDE
# 0                         Allentown    PA     USA  40.65236  -75.44040
# 1                           Abilene    TX     USA  32.41132  -99.68190
# 2                       Albuquerque    NM     USA  35.04022 -106.60919
# ...

# %%
type(flights)
# Out:
# pandas.core.frame.DataFrame

# %%
flights.columns
# Out:
# Index(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'FLIGHT_NUMBER',
#        'TAIL_NUMBER', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
#        'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY', 'TAXI_OUT',
#        'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE',
#        'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME',
#        'ARRIVAL_DELAY', 'DIVERTED', 'CANCELLED', 'CANCELLATION_REASON',
#        'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY'],
#       dtype='object')

# %%
flights.sample(5)
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 4435654  2015     10    4            7      EV           4972      N153PQ
# 3695140  2015      8   18            2      AA           2115      N821AW
# 896783   2015      2   28            6      WN           4267      N500WR
# 1064746  2015      3   11            3      US           1842      N702UW
# 1832202  2015      4   27            1      MQ           3558      N692MQ
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT SCHEDULED_DEPARTURE DEPARTURE_TIME  \
# 4435654          11433               10994                1000           0957
# 3695140            LGA                 DCA                0600           0602
# 896783             DCA                 MDW                1745           1738
# 1064746            PVD                 CLT                0959           0955
# 1832202            CLL                 DFW                1510           1509
#
# ...

# %%
flights.shape
# Out:
# (5819079, 31)

# %%
display(airlines)
# Out:
#    IATA_CODE                       AIRLINE
# 0         UA         United Air Lines Inc.
# 1         AA        American Airlines Inc.
# 2         US               US Airways Inc.
# 3         F9        Frontier Airlines Inc.
# 4         B6               JetBlue Airways
# 5         OO         Skywest Airlines Inc.
# 6         AS          Alaska Airlines Inc.
# 7         NK              Spirit Air Lines
# 8         WN        Southwest Airlines Co.
# 9         DL          Delta Air Lines Inc.
# 10        EV   Atlantic Southeast Airlines
# 11        HA        Hawaiian Airlines Inc.
# 12        MQ  American Eagle Airlines Inc.
# 13        VX                Virgin America

# %%
#flights.groupby('FLIGHT_NUMBER').agg({'FLIGHT_NUMBER':'value_counts'})
print(len(flights['FLIGHT_NUMBER'].unique()))
flights['FLIGHT_NUMBER'].value_counts(ascending=True)
# Out:
# 6952
# 6881       1
# 8410       1
# 6850       1
# 6689       1
# 6690       1
#         ...
# 403     3370
# 188     3386
# 326     3513
# 327     3554
# 469     3975
# Name: FLIGHT_NUMBER, Length: 6952, dtype: int64

# %%
count_flights = flights[['YEAR', 'MONTH', 'DAY', 'AIRLINE', 'FLIGHT_NUMBER']].value_counts(ascending=True)
display(count_flights)
# Out:
# YEAR  MONTH  DAY  AIRLINE  FLIGHT_NUMBER
# 2015  1      1    AA       1                1
#       8      11   MQ       3219             1
#                            3221             1
#                            3225             1
#                            3226             1
#                                            ..
#       4      29   WN       891              8
#       6      7    WN       1778             8
#       2      3    WN       576              8
#       6      23   WN       232              8
#              18   WN       232              8
# Length: 4117420, dtype: int64

# %%
count_flights
# Out:
# YEAR  MONTH  DAY  AIRLINE  FLIGHT_NUMBER
# 2015  1      1    AA       1                1
#       8      11   MQ       3219             1
#                            3221             1
#                            3225             1
#                            3226             1
#                                            ..
#       4      29   WN       891              8
#       6      7    WN       1778             8
#       2      3    WN       576              8
#       6      23   WN       232              8
#              18   WN       232              8
# Length: 4117420, dtype: int64

# %%
type(count_flights)
# Out:
# pandas.core.series.Series

# %%
a = count_flights[count_flights>5]
airlines = set()
for i in a.index:
    airlines.add(i[3])
airlines
# Out:
# {'WN'}

# %%
flights[(flights['MONTH']==4) & (flights['DAY']==29) & (flights['AIRLINE']=='WN') & (flights['FLIGHT_NUMBER']==891)]
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 1857265  2015      4   29            3      WN            891      N385SW
# 1858808  2015      4   29            3      WN            891      N385SW
# 1860311  2015      4   29            3      WN            891      N385SW
# 1864205  2015      4   29            3      WN            891      N385SW
# 1865118  2015      4   29            3      WN            891      N385SW
# 1866850  2015      4   29            3      WN            891      N385SW
# 1868601  2015      4   29            3      WN            891      N226WN
# 1871240  2015      4   29            3      WN            891      N226WN
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT SCHEDULED_DEPARTURE DEPARTURE_TIME  \
# 1857265            DAL                 TUL                0715           0715
# 1858808            TUL                 DEN                0845           0837
# ...

# %%
flights[(flights['MONTH']==4) & (flights['AIRLINE']=='WN') & (flights['FLIGHT_NUMBER']==892)]
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 1404948  2015      4    1            3      WN            892      N906WN
# 1421753  2015      4    2            4      WN            892         NaN
# 1438735  2015      4    3            5      WN            892      N499WN
# 1468703  2015      4    5            7      WN            892      N7715E
# 1484755  2015      4    6            1      WN            892      N441WN
# 1529488  2015      4    8            3      WN            892      N785SW
# 1530607  2015      4    8            3      WN            892      N785SW
# 1546281  2015      4    9            4      WN            892      N7745A
# 1547417  2015      4    9            4      WN            892      N7745A
# 1563165  2015      4   10            5      WN            892      N7717D
# 1564286  2015      4   10            5      WN            892      N7717D
# 1592538  2015      4   12            7      WN            892      N7724A
# ...

# %%
flight891 = flights[flights['FLIGHT_NUMBER']==891]

# %%
flight891[['FLIGHT_NUMBER', 'TAIL_NUMBER', 'AIRLINE']].value_counts(ascending=False)
# Out:
# FLIGHT_NUMBER  TAIL_NUMBER  AIRLINE
# 891            N395SW       WN         29
#                N524SW       WN         19
#                N640SW       WN         17
#                N609SW       WN         17
#                N655WN       WN         16
#                                        ..
#                N907DE       DL          1
#                N907DL       DL          1
#                N373DA       DL          1
#                N3735D       DL          1
#                N910DL       DL          1
# Length: 675, dtype: int64

# %%
flights[['TAIL_NUMBER', 'AIRLINE']].value_counts(ascending=False)
# Out:
# TAIL_NUMBER  AIRLINE
# N480HA       HA         3768
# N488HA       HA         3723
# N484HA       HA         3723
# N493HA       HA         3585
# N478HA       HA         3577
#                         ...
# N121UA       UA            1
# N7LEAA       AA            1
# N175UA       UA            1
# N860NW       DL            1
# N840MH       DL            1
# Length: 5234, dtype: int64

# %%
df = pd.DataFrame()
df['one to one']=flights.groupby('TAIL_NUMBER')['AIRLINE'].nunique()

# %%
df[df['one to one']>1]
# Out:
#              one to one
# TAIL_NUMBER
# N102UW                2
# N103US                2
# N104UW                2
# N105UW                2
# N107US                2
# ...                 ...
# N961UW                2
# N963UW                2
# N965UW                2
# N967UW                2
# N971UY                2
#
# [337 rows x 1 columns]

# %%
flights[flights['TAIL_NUMBER']=='N102UW']
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 3284     2015      1    1            4      US           1882      N102UW
# 4510     2015      1    1            4      US            713      N102UW
# 6907     2015      1    1            4      US           1840      N102UW
# 12648    2015      1    1            4      US           1919      N102UW
# 17208    2015      1    2            5      US           1753      N102UW
# ...       ...    ...  ...          ...     ...            ...         ...
# 5789417  2015     12   29            2      AA           1971      N102UW
# 5792719  2015     12   30            3      AA            879      N102UW
# 5805668  2015     12   30            3      AA           1971      N102UW
# 5808533  2015     12   31            4      AA            879      N102UW
# 5811848  2015     12   31            4      AA           1837      N102UW
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT SCHEDULED_DEPARTURE DEPARTURE_TIME  \
# ...

# %%
def isOnetoOne(df, col1, col2):
    '''check for one to one relationship for two columns'''

    fir
