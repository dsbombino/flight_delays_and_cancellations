# %%
import reads.reads as r
import pandas as pd
pd.set_option("display.max_columns", None)

# %%
stream_airlines = 'C:./Data/2015 Flight Delays and Cancellations/airlines.csv'
stream_airports = 'C:./Data/2015 Flight Delays and Cancellations/airports.csv'
stream_flights = 'C:./Data/2015 Flight Delays and Cancellations/flights.csv'

# %%
flights = r.read_flight(stream_flights)
flights
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0        2015      1    1            4      AS             98      N407AS
# 1        2015      1    1            4      AA           2336      N3KUAA
# 2        2015      1    1            4      US            840      N171US
# 3        2015      1    1            4      AA            258      N3HYAA
# 4        2015      1    1            4      AS            135      N527AS
# ...       ...    ...  ...          ...     ...            ...         ...
# 5819074  2015     12   31            4      B6            688      N657JB
# 5819075  2015     12   31            4      B6            745      N828JB
# 5819076  2015     12   31            4      B6           1503      N913JB
# 5819077  2015     12   31            4      B6            333      N527JB
# 5819078  2015     12   31            4      B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT SCHEDULED_DEPARTURE  ...  \
# 0                  ANC                 SEA                0005  ...
# 1                  LAX                 PBI                0010  ...
# 2                  SFO                 CLT                0020  ...
# 3                  LAX                 MIA                0020  ...
# 4                  SEA                 ANC                0025  ...
# ...                ...                 ...                 ...  ...
# 5819074            LAX                 BOS                2359  ...
# 5819075            JFK                 PSE                2359  ...
# 5819076            JFK                 SJU                2359  ...
# 5819077            MCO                 SJU                2359  ...
# 5819078            JFK                 BQN                2359  ...
#
#         ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED CANCELLED  CANCELLATION_REASON  \
# 0               0408          -22.0         0         0                  NaN
# 1               0741           -9.0         0         0                  NaN
# 2               0811            5.0         0         0                  NaN
# 3               0756           -9.0         0         0                  NaN
# 4               0259          -21.0         0         0                  NaN
# ...              ...            ...       ...       ...                  ...
# 5819074         0753          -26.0         0         0                  NaN
# 5819075         0430          -16.0         0         0                  NaN
# 5819076         0432           -8.0         0         0                  NaN
# 5819077         0330          -10.0         0         0                  NaN
# 5819078         0442            2.0         0         0                  NaN
#
#          AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY LATE_AIRCRAFT_DELAY  \
# 0                     NaN             NaN            NaN                 NaN
# 1                     NaN             NaN            NaN                 NaN
# 2                     NaN             NaN            NaN                 NaN
# 3                     NaN             NaN            NaN                 NaN
# 4                     NaN             NaN            NaN                 NaN
# ...                   ...             ...            ...                 ...
# 5819074               NaN             NaN            NaN                 NaN
# 5819075               NaN             NaN            NaN                 NaN
# 5819076               NaN             NaN            NaN                 NaN
# 5819077               NaN             NaN            NaN                 NaN
# 5819078               NaN             NaN            NaN                 NaN
#
#          WEATHER_DELAY
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 5819074            NaN
# 5819075            NaN
# 5819076            NaN
# 5819077            NaN
# 5819078            NaN
#
# [5819079 rows x 31 columns]

# %%
airlines = r.read_airlines(stream_airlines)
airlines
# Out:
#    IATA_CODE                       AIRLINE
# 0         UA         United Air Lines Inc.
# 1         AA        American Airlines Inc.
# 2         US               US Airways Inc.
# 3         F9        Frontier Airlines Inc.
# 4         B6               JetBlue Airways
# 5         OO         Skywest Airlines Inc.
# 6         AS          Alaska Airlines Inc.
# 7         NK              Spirit Air Lines
# 8         WN        Southwest Airlines Co.
# 9         DL          Delta Air Lines Inc.
# 10        EV   Atlantic Southeast Airlines
# 11        HA        Hawaiian Airlines Inc.
# 12        MQ  American Eagle Airlines Inc.
# 13        VX                Virgin America

# %%
airports = r.read_airports(stream_airports)
airports
# Out:
#     IATA_CODE                              AIRPORT  \
# 0         ABE  Lehigh Valley International Airport
# 1         ABI             Abilene Regional Airport
# 2         ABQ    Albuquerque International Sunport
# 3         ABR            Aberdeen Regional Airport
# 4         ABY   Southwest Georgia Regional Airport
# ..        ...                                  ...
# 317       WRG                     Wrangell Airport
# 318       WYS               Westerly State Airport
# 319       XNA  Northwest Arkansas Regional Airport
# 320       YAK                      Yakutat Airport
# 321       YUM           Yuma International Airport
#
#                                CITY STATE COUNTRY  LATITUDE  LONGITUDE
# 0                         Allentown    PA     USA  40.65236  -75.44040
# 1                           Abilene    TX     USA  32.41132  -99.68190
# 2                       Albuquerque    NM     USA  35.04022 -106.60919
# 3                          Aberdeen    SD     USA  45.44906  -98.42183
# 4                            Albany    GA     USA  31.53552  -84.19447
# ..                              ...   ...     ...       ...        ...
# 317                        Wrangell    AK     USA  56.48433 -132.36982
# 318                West Yellowstone    MT     USA  44.68840 -111.11764
# 319  Fayetteville/Springdale/Rogers    AR     USA  36.28187  -94.30681
# 320                         Yakutat    AK     USA  59.50336 -139.66023
# 321                            Yuma    AZ     USA  32.65658 -114.60597
#
# [322 rows x 7 columns]

# %%
type(flights)
# Out:
# pandas.core.frame.DataFrame

# %%
flights.columns
# Out:
# Index(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'FLIGHT_NUMBER',
#        'TAIL_NUMBER', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
#        'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY', 'TAXI_OUT',
#        'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE',
#        'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME',
#        'ARRIVAL_DELAY', 'DIVERTED', 'CANCELLED', 'CANCELLATION_REASON',
#        'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY'],
#       dtype='object')

# %%
flights.sample(5)
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 5244228  2015     11   24            2      AA           1682      N536UW
# 1739138  2015      4   21            2      WN            224      N462WN
# 1216639  2015      3   20            5      AA           1210      N3HMAA
# 5437575  2015     12    7            1      AA            679      N981UY
# 4841756  2015     10   29            4      WN           1277      N610WN
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT SCHEDULED_DEPARTURE DEPARTURE_TIME  \
# 5244228            LAX                 LAS                1630           1625
# 1739138            LAX                 SLC                1825           1832
# 1216639            PHL                 MIA                1330           1324
# 5437575            CLT                 PHX                1125           1133
# 4841756          11292               10693                1915           1923
#
#          DEPARTURE_DELAY  TAXI_OUT WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  \
# 5244228             -5.0      36.0       1701            77.0          86.0
# 1739138              7.0      14.0       1846           100.0         101.0
# 1216639             -6.0      52.0       1416           178.0         231.0
# 5437575              8.0      31.0       1204           278.0         276.0
# 4841756              8.0      13.0       1936           150.0         141.0
#
#          AIR_TIME  DISTANCE WHEELS_ON  TAXI_IN SCHEDULED_ARRIVAL ARRIVAL_TIME  \
# 5244228      44.0       236      1745      6.0              1747         1751
# 1739138      81.0       590      2107      6.0              2105         2113
# 1216639     154.0      1013      1650     25.0              1628         1715
# 5437575     241.0      1773      1405      4.0              1403         1409
# 4841756     121.0      1014      2237      7.0              2245         2244
#
#          ARRIVAL_DELAY  DIVERTED  CANCELLED CANCELLATION_REASON  \
# 5244228            4.0         0          0                 NaN
# 1739138            8.0         0          0                 NaN
# 1216639           47.0         0          0                 NaN
# 5437575            6.0         0          0                 NaN
# 4841756           -1.0         0          0                 NaN
#
#          AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 5244228               NaN             NaN            NaN                  NaN
# 1739138               NaN             NaN            NaN                  NaN
# 1216639              47.0             0.0            0.0                  0.0
# 5437575               NaN             NaN            NaN                  NaN
# 4841756               NaN             NaN            NaN                  NaN
#
#          WEATHER_DELAY
# 5244228            NaN
# 1739138            NaN
# 1216639            0.0
# 5437575            NaN
# 4841756            NaN

# %%
flights.shape
# Out:
# (5819079, 31)

# %%
#flights.groupby('FLIGHT_NUMBER').agg({'FLIGHT_NUMBER':'value_counts'})
print(len(flights['FLIGHT_NUMBER'].unique()))
flights['FLIGHT_NUMBER'].value_counts(ascending=True)
# Out:
# 6952
# 6881       1
# 8410       1
# 6850       1
# 6689       1
# 6690       1
#         ...
# 403     3370
# 188     3386
# 326     3513
# 327     3554
# 469     3975
# Name: FLIGHT_NUMBER, Length: 6952, dtype: int64

# %%
flights[['YEAR', 'MONTH', 'DAY', 'AIRLINE', 'FLIGHT_NUMBER']].value_counts(ascending=True)
# Out:
# YEAR  MONTH  DAY  AIRLINE  FLIGHT_NUMBER
# 2015  1      1    AA       1                1
#       8      11   MQ       3219             1
#                            3221             1
#                            3225             1
#                            3226             1
#                                            ..
#       4      29   WN       891              8
#       6      7    WN       1778             8
#       2      3    WN       576              8
#       6      23   WN       232              8
#              18   WN       232              8
# Length: 4117420, dtype: int64

# %%
flights['MONTH']==4
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#            ...
# 5819074    True
# 5819075    True
# 5819076    True
# 5819077    True
# 5819078    True
# Name: MONTH, Length: 5819079, dtype: bool
